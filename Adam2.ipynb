# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('37_25.csv', header=None)
model = PCA(svd_solver='full', n_components=2)

# %%
a = model.fit_transform(df)
plt.scatter(a[:,0], a[:,1])

# %%
a
# Out:
# array([[-2.82041366e+01, -1.14726983e+01],
#        [ 1.39648803e+01, -3.22371213e+01],
#        [ 1.69416688e+01, -3.42170302e+01],
#        [-2.55515803e+01, -1.47533091e+01],
#        [ 3.10849996e+00,  4.15830287e+01],
#        [ 1.37042844e+01, -3.00036263e+01],
#        [-2.79203172e+01, -1.17962692e+01],
#        [ 1.34760119e+01, -3.05099029e+01],
#        [ 1.49771303e+01, -3.04019661e+01],
#        [-2.66203826e+01, -1.33449684e+01],
#        [ 4.03497558e+01,  6.14495090e-01],
#        [ 5.12500321e+00,  4.11612325e+01],
#        [-3.46431452e+01,  1.63859498e-01],
#        [-3.33971414e+01, -7.81743348e-01],
#        [-2.55477226e+01, -1.15652671e+01],
#        [-3.32582175e+01,  1.30075561e+00],
#        [ 3.78494112e+01,  6.00962170e-01],
#        [ 1.91424433e+01, -2.82056496e+01],
#        [-3.13878627e+01,  1.32577150e+00],
#        [-2.44077893e+01, -1.14560300e+01],
#        [ 3.99652450e+01,  1.94338188e+00],
#        [ 4.25675950e+00,  4.19770816e+01],
# ...

# %%
a = model.fit_transform(df)
plt.scatter(a[:,0], a[:,1])

# %%
model.explained_variance_ratio_.sum()
# Out:
# 0.703512256150451

# %%
model.
# Out:
#   Cell In[10], line 1
#     model.
#           ^
# SyntaxError: invalid syntax

# %%
a = pd.read_csv('Adam_reduced.csv', header=None, sep=';')

# %%
b = pd.read_csv('Adam_loading.csv', header=None, sep=';')

# %%
a.values@b.values.T
# Out:
# array([[1.13031992e-14, 1.09019050e-13, 3.67543477e-15, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.13031992e-14, 1.09019050e-13, 3.67543477e-15, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.13031992e-14, 1.09019050e-13, 3.67543477e-15, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [1.13031992e-14, 1.09019050e-13, 3.67543477e-15, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.13031992e-14, 1.09019050e-13, 3.67543477e-15, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.13031992e-14, 1.09019050e-13, 3.67543477e-15, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
plt.imshow(a.values@b.values.T,cmap='gray')
