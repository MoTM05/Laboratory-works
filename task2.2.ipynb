# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('X_reduced_417(karen).csv', header=None, sep=';')

# %%
b = pd.read_csv('X_loadings_417(karen).csv', header=None, sep=';')

# %%
a.values@b.values.T

# %%
plt.imshow(a.values@b.values.T,cmap='gray')

# %%
plt.imshow(a.values@b.values.T,cmap='gray')

# %%
b.values.T
# Out:
# array([[-4.91879509e-18, -0.00000000e+00, -5.55111512e-17,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -5.63463123e-02, -9.20972073e-02,
#         -9.63698362e-02, -9.20972073e-02, -8.36478118e-02,
#          3.72797193e-03,  6.88214955e-03,  1.16162830e-02,
#         -1.82227020e-02, -9.96516072e-02, -1.66537112e-01,
#         -1.80405534e-01, -1.79253261e-01, -1.85445708e-01,
#         -7.71465758e-02,  8.94276859e-03,  2.51020924e-02,
#          8.94276859e-03, -8.55185980e-02, -2.27924694e-01,
#         -2.19690857e-01, -2.20843130e-01, -2.17609509e-01,
#         -1.18996100e-01, -3.66853435e-03,  4.04398850e-02,
#          3.10467778e-02, -5.25570611e-03, -1.78855919e-01,
# ...
